# %% [markdown]
# 1. ให้ระบบการซื้อขายมา แล้วจะสอบถามว่าระบบไหนบ้างที่เกิดปัญหาการซื้อหลายครั้งติดกันโดยที่ยังไม่เกิดการขายหรือเกิดการขายติดกันหลายครั้งโดยไม่เกิดการซือ
# 2. สั่งให้คำนวณดัชนีต่างที่ใช้ในการซื้อขายเชิงเทคนิค และบันทึกเป็น dataflames
# 3. ให้หาสัญญาณซื้อขายโดยจะกำหนดให้ว่าซื้อเมื่อไหร่ขายเมื่อไหร่ (เขียนฟังก์ชันหาสัญญาณซื้อขาย)
# 4. จำลองการซื้อขาย simulate trading โดยมีการระบุเงื่อนไขต่างๆว่า ค่าคอมเป็นเท่าไหร่ มีการซื้อขายทั้งหมดกี่ปี (แปลงเงื่อนไขให้เป็นไปตามที่โจทย์สั่ง)
# 5. การปรับจูนพารามิเตอร์ โดยให้มาว่าปรับจูนพารามิเตอร์ตัวไหนมีค่าเป็นเท่าไหร่บ้าง จะต้องเขียนไฟล์ที่โจทย์กำหนดให้

# %% [markdown]
# - ตอนสอบมีไฟล์ที่จำเป็นให้
# - แต่ละข้อทำแยกเป็น 1 โฟลเดอร์ แต่ละโฟลเดอร์จะมีไฟล์ย่อยอยู่ข้างในที่จำเป็น และให้ไว้ทั้งหมด
# - จะต้องเขียนไฟล์ทั้งหมด หรือแก้ไขให้ได้ตามที่โจทย์กำหนด
# - ไฟล์ทุกไฟล์ save เป็น .py
# - 3 ชม.
# - ชื่อไฟล์ใหญ่สุดตั้งชื่อว่า 2010511104009พัชร
# - และ zip ทั้ง folder
# - ส่งใน msteam
